# %% [markdown]
# <a href="https://colab.research.google.com/github/Sourav-Manik/AI-Assignments/blob/main/Assignment_3_Data_Preprocessing_(Cropping_Image).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import cv2
from matplotlib import pyplot as plt
plt.style.use('seaborn')
from google.colab.patches import cv2_imshow

# %% [markdown]
# #Image 1

# %%
image_1 = cv2.imread('/content/image_org_1.PNG')

# %%
# Check the type of read image
print(type(image_1))
# Out:
# <class 'numpy.ndarray'>

# %%
plt.imshow(image_1,cmap = 'gray')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
y=200
x=65
h=400
w=300
crop_image = image_1[x:w, y:h]
cv2_imshow(crop_image)
# Out:
# <PIL.Image.Image image mode=RGB size=200x235 at 0x7F7201E87E20>

# %% [markdown]
# #Image 2

# %%
image_2 = cv2.imread('/content/image_org_2.PNG')

# %%
plt.imshow(image_2,cmap = 'gray')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
y=50
x=50
h=250
w=250
crop_image2 = image_2[x:w, y:h]
cv2_imshow(crop_image2)
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7F7204903790>
