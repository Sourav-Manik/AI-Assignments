# %% [markdown]
# <a href="https://colab.research.google.com/github/Sourav-Manik/AI-Assignments/blob/main/Assignment_9_Face_Detection_using_OpenCV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
from google.colab.patches import cv2_imshow

# %%
#downloading the trained classifier XML file (haarcascade_frontalface_default.xml), which is available in OpenCv’s GitHub repository and saveing it to our working location.
face_cascade=cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_frontalface_default.xml")

# %%
#downloading any images with faces
img = cv2.imread('/content/Indian_cricket_players_face.jpeg')

# %%
#The detection works only on grayscale images. So it is important to convert the color image to grayscale.
gray_img=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

# %%
faces = face_cascade.detectMultiScale(gray_img,scaleFactor=1.2,minNeighbors=4)

# Since some faces may be closer to the camera, they would appear bigger than the faces in the back. The scale factor compensates for this.
#The detection algorithm uses a moving window to detect objects. minNeighbors defines how many objects are detected near the current one before it declares the face found.

print("Total Faces:",len(faces))
print("Face Coordinates:",faces)
# Out:
# Total Faces: 21
# Face Coordinates: [[ 684   96   63   63]
#  [ 496  114   58   58]
#  [ 588  123   69   69]
#  [ 377  134   63   63]
#  [ 903  163   54   54]
#  [ 144  117   70   70]
#  [ 702  191   61   61]
#  [ 436  204   63   63]
#  [ 818  214   63   63]
#  [ 338  230   60   60]
#  [ 434  324   65   65]
#  [ 196  339   61   61]
#  [ 811  342   58   58]
#  [ 662  376   58   58]
#  [1089  347   69   69]
#  [ 951  363   68   68]
#  [ 542  394   67   67]
#  [  48  358   79   79]
#  [ 312  390   70   70]
#  [ 769  484   61   61]
#  [ 129  452   69   69]]

# %%
#Draw Rectangle on Face

for x,y,w,h in faces:
    img=cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,0),3)

# %%
cv2_imshow(img)
cv2.waitKey(0)
# cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=1196x861 at 0x7FF6876FB1C0>
# -1
